# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("datasets/titanic.csv")
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %% [markdown]
# 1. sibsp - Siblings and spouse count
#
# 2. parch - Parent and children count
#
# missing values are found in the columns like age, fare, embark, cabin
#
# embark - port

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %% [markdown]
# # Data cleaning
#
# 1. Check for duplicates and handle them
#
# 2. handle the missing values
#
# 3. check for invalid datatypes and handle them

# %%
df.duplicated()

# no duplicates present in the dataset
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Length: 1309, dtype: bool

# %%
age_median = df['age'].median()

# %%
fare_median = df['fare'].median()

# %%
df['age'] = df['age'].fillna(age_median)

# %%
df['fare'] = df['fare'].fillna(fare_median)

# %%
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %%
df['embarked'].mode()
# Out:
# 0    S
# Name: embarked, dtype: object

# %%
df['embarked'].mode()[0]
# Out:
# 'S'

# %%
df['embarked'] = df['embarked'].fillna(df['embarked'].mode()[0])
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1309 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1309 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1309 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
df = df.dropna(axis=1)
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare embarked  survived
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1309 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1309 non-null   float64
#  8   embarked  1309 non-null   object
#  9   survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 102.4+ KB

# %% [markdown]
# All the columns have valid data type

# %% [markdown]
# # Data Transformation (or) Feature Engineering

# %%
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare embarked  survived
# ...

# %%
df = df.rename(columns={"sex": "gender", "embarked":"port"})
df
# Out:
#       pclass                                             name  gender  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare port  survived
# 0     29.0000      0      0   24160  211.3375    S         1
# ...

# %%
df['pclass'].unique()
# Out:
# array([1, 2, 3])

# %%
df['name'].str.split()
# Out:
# 0                      [Allen,, Miss., Elisabeth, Walton]
# 1                     [Allison,, Master., Hudson, Trevor]
# 2                       [Allison,, Miss., Helen, Loraine]
# 3              [Allison,, Mr., Hudson, Joshua, Creighton]
# 4       [Allison,, Mrs., Hudson, J, C, (Bessie, Waldo,...
#                               ...
# 1304                             [Zabour,, Miss., Hileni]
# 1305                            [Zabour,, Miss., Thamine]
# 1306                        [Zakarian,, Mr., Mapriededer]
# 1307                              [Zakarian,, Mr., Ortin]
# 1308                               [Zimmerman,, Mr., Leo]
# Name: name, Length: 1309, dtype: object

# %%
df['name'].str.split(",", expand=True)
# Out:
#               0                                        1
# 0         Allen                   Miss. Elisabeth Walton
# 1       Allison                    Master. Hudson Trevor
# 2       Allison                      Miss. Helen Loraine
# 3       Allison              Mr. Hudson Joshua Creighton
# 4       Allison   Mrs. Hudson J C (Bessie Waldo Daniels)
# ...         ...                                      ...
# 1304     Zabour                             Miss. Hileni
# 1305     Zabour                            Miss. Thamine
# 1306   Zakarian                          Mr. Mapriededer
# 1307   Zakarian                                Mr. Ortin
# 1308  Zimmerman                                  Mr. Leo
#
# [1309 rows x 2 columns]

# %%
df[['lname', 'temp']] = df['name'].str.split(",", expand=True)
df
# Out:
#       pclass                                             name  gender  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare port  survived      lname  \
# ...

# %%
df['temp'].str.split(".", expand=True,n=1)
# Out:
#             0                                   1
# 0        Miss                    Elisabeth Walton
# 1      Master                       Hudson Trevor
# 2        Miss                       Helen Loraine
# 3          Mr             Hudson Joshua Creighton
# 4         Mrs   Hudson J C (Bessie Waldo Daniels)
# ...       ...                                 ...
# 1304     Miss                              Hileni
# 1305     Miss                             Thamine
# 1306       Mr                         Mapriededer
# 1307       Mr                               Ortin
# 1308       Mr                                 Leo
#
# [1309 rows x 2 columns]

# %%
df[['courtesy_title', 'fname']] = df['temp'].str.split(".", expand=True,n=1)
df
# Out:
#       pclass                                             name  gender  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare port  survived      lname  \
# ...

# %%
df['courtesy_title'] = df['courtesy_title'].str.strip()
df
# Out:
#       pclass                                             name  gender  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare port  survived      lname  \
# ...

# %% [markdown]
# # df['fname'] = df['fname'].str.strip()
# # df['lname'] = df['lname'].str.strip()
# # df

# %%
for col_names in ['fname', 'lname', 'courtesy_title']:
    df[col_names] = df[col_names].str.strip()

df
# Out:
#       pclass                                             name  gender  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare port  survived      lname  \
# ...

# %%
df['gender'] = df['gender'].str.title()
df
# Out:
#       pclass                                             name  gender  \
# 0          1                    Allen, Miss. Elisabeth Walton  Female
# 1          1                   Allison, Master. Hudson Trevor    Male
# 2          1                     Allison, Miss. Helen Loraine  Female
# 3          1             Allison, Mr. Hudson Joshua Creighton    Male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  Female
# 1305       3                            Zabour, Miss. Thamine  Female
# 1306       3                        Zakarian, Mr. Mapriededer    Male
# 1307       3                              Zakarian, Mr. Ortin    Male
# 1308       3                               Zimmerman, Mr. Leo    Male
#
#           age  sibsp  parch  ticket      fare port  survived      lname  \
# ...

# %%
df['age'] = df['age'].round(1)
df
# Out:
#       pclass                                             name  gender   age  \
# 0          1                    Allen, Miss. Elisabeth Walton  Female  29.0
# 1          1                   Allison, Master. Hudson Trevor    Male   0.9
# 2          1                     Allison, Miss. Helen Loraine  Female   2.0
# 3          1             Allison, Mr. Hudson Joshua Creighton    Male  30.0
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female  25.0
# ...      ...                                              ...     ...   ...
# 1304       3                             Zabour, Miss. Hileni  Female  14.5
# 1305       3                            Zabour, Miss. Thamine  Female  28.0
# 1306       3                        Zakarian, Mr. Mapriededer    Male  26.5
# 1307       3                              Zakarian, Mr. Ortin    Male  27.0
# 1308       3                               Zimmerman, Mr. Leo    Male  29.0
#
# ...

# %%
df['fam_cnt'] = df['sibsp'] + df['parch']
df
# Out:
#       pclass                                             name  gender   age  \
# 0          1                    Allen, Miss. Elisabeth Walton  Female  29.0
# 1          1                   Allison, Master. Hudson Trevor    Male   0.9
# 2          1                     Allison, Miss. Helen Loraine  Female   2.0
# 3          1             Allison, Mr. Hudson Joshua Creighton    Male  30.0
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female  25.0
# ...      ...                                              ...     ...   ...
# 1304       3                             Zabour, Miss. Hileni  Female  14.5
# 1305       3                            Zabour, Miss. Thamine  Female  28.0
# 1306       3                        Zakarian, Mr. Mapriededer    Male  26.5
# 1307       3                              Zakarian, Mr. Ortin    Male  27.0
# 1308       3                               Zimmerman, Mr. Leo    Male  29.0
#
# ...

# %%
df = df.sort_values(by='ticket', ascending=True)
df
# Out:
#      pclass                                               name  gender   age  \
# 67        1                               Cherry, Miss. Gladys  Female  30.0
# 245       1  Rothes, the Countess. of (Lucy Noel Martha Dye...  Female  33.0
# 195       1                              Maioni, Miss. Roberta  Female  16.0
# 289       1                                Taussig, Miss. Ruth  Female  18.0
# 291       1             Taussig, Mrs. Emil (Tillie Mandelbaum)  Female  39.0
# ..      ...                                                ...     ...   ...
# 63        1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  Female  47.0
# 62        1                        Chaffee, Mr. Herbert Fuller    Male  46.0
# 433       2                                 Harris, Mr. Walter    Male  30.0
# 81        1                       Crosby, Capt. Edward Gifford    Male  70.0
# 82        1                            Crosby, Miss. Harriet R  Female  36.0
#
# ...

# %%
df['ticket'].value_counts()
# Out:
# ticket
# CA. 2343            11
# CA 2144              8
# 1601                 8
# S.O.C. 14879         7
# 347082               7
#                     ..
# SOTON/O2 3101272     1
# STON/O2. 3101283     1
# STON/O2. 3101282     1
# STON/O2. 3101271     1
# 112050               1
# Name: count, Length: 929, dtype: int64

# %%
tik_df = df['ticket'].value_counts().reset_index()

# %%
df = pd.merge(df, tik_df, on='ticket', how="inner")
df
# Out:
#       pclass                                               name  gender   age  \
# 0          1                               Cherry, Miss. Gladys  Female  30.0
# 1          1  Rothes, the Countess. of (Lucy Noel Martha Dye...  Female  33.0
# 2          1                              Maioni, Miss. Roberta  Female  16.0
# 3          1                                Taussig, Miss. Ruth  Female  18.0
# 4          1             Taussig, Mrs. Emil (Tillie Mandelbaum)  Female  39.0
# ...      ...                                                ...     ...   ...
# 1304       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  Female  47.0
# 1305       1                        Chaffee, Mr. Herbert Fuller    Male  46.0
# 1306       2                                 Harris, Mr. Walter    Male  30.0
# 1307       1                       Crosby, Capt. Edward Gifford    Male  70.0
# 1308       1                            Crosby, Miss. Harriet R  Female  36.0
#
# ...

# %%
df = df.rename(columns={'count': 'psg_cnt'})
df
# Out:
#       pclass                                               name  gender   age  \
# 0          1                               Cherry, Miss. Gladys  Female  30.0
# 1          1  Rothes, the Countess. of (Lucy Noel Martha Dye...  Female  33.0
# 2          1                              Maioni, Miss. Roberta  Female  16.0
# 3          1                                Taussig, Miss. Ruth  Female  18.0
# 4          1             Taussig, Mrs. Emil (Tillie Mandelbaum)  Female  39.0
# ...      ...                                                ...     ...   ...
# 1304       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  Female  47.0
# 1305       1                        Chaffee, Mr. Herbert Fuller    Male  46.0
# 1306       2                                 Harris, Mr. Walter    Male  30.0
# 1307       1                       Crosby, Capt. Edward Gifford    Male  70.0
# 1308       1                            Crosby, Miss. Harriet R  Female  36.0
#
# ...

# %%
df['fare'] = (df['fare']/df['psg_cnt']).round(1)
df
# Out:
#       pclass                                               name  gender   age  \
# 0          1                               Cherry, Miss. Gladys  Female  30.0
# 1          1  Rothes, the Countess. of (Lucy Noel Martha Dye...  Female  33.0
# 2          1                              Maioni, Miss. Roberta  Female  16.0
# 3          1                                Taussig, Miss. Ruth  Female  18.0
# 4          1             Taussig, Mrs. Emil (Tillie Mandelbaum)  Female  39.0
# ...      ...                                                ...     ...   ...
# 1304       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  Female  47.0
# 1305       1                        Chaffee, Mr. Herbert Fuller    Male  46.0
# 1306       2                                 Harris, Mr. Walter    Male  30.0
# 1307       1                       Crosby, Capt. Edward Gifford    Male  70.0
# 1308       1                            Crosby, Miss. Harriet R  Female  36.0
#
# ...

# %%
df['port'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df['port'] = df['port'].replace({"S": "Southampton", "C": "Cherbourg", "Q": "Queens"})
df
# Out:
#       pclass                                               name  gender   age  \
# 0          1                               Cherry, Miss. Gladys  Female  30.0
# 1          1  Rothes, the Countess. of (Lucy Noel Martha Dye...  Female  33.0
# 2          1                              Maioni, Miss. Roberta  Female  16.0
# 3          1                                Taussig, Miss. Ruth  Female  18.0
# 4          1             Taussig, Mrs. Emil (Tillie Mandelbaum)  Female  39.0
# ...      ...                                                ...     ...   ...
# 1304       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  Female  47.0
# 1305       1                        Chaffee, Mr. Herbert Fuller    Male  46.0
# 1306       2                                 Harris, Mr. Walter    Male  30.0
# 1307       1                       Crosby, Capt. Edward Gifford    Male  70.0
# 1308       1                            Crosby, Miss. Harriet R  Female  36.0
#
# ...

# %%
df['name'] = df['fname'] + ' ' + df['lname']
df
# Out:
#       pclass                                               name  gender   age  \
# 0          1                                      Gladys Cherry  Female  30.0
# 1          1          of (Lucy Noel Martha Dyer-Edwards) Rothes  Female  33.0
# 2          1                                     Roberta Maioni  Female  16.0
# 3          1                                       Ruth Taussig  Female  18.0
# 4          1                   Emil (Tillie Mandelbaum) Taussig  Female  39.0
# ...      ...                                                ...     ...   ...
# 1304       1  Herbert Fuller (Carrie Constance Toogood) Chaffee  Female  47.0
# 1305       1                             Herbert Fuller Chaffee    Male  46.0
# 1306       2                                      Walter Harris    Male  30.0
# 1307       1                              Edward Gifford Crosby    Male  70.0
# 1308       1                                   Harriet R Crosby  Female  36.0
#
# ...

# %%
df = df.drop(columns=['lname', 'temp', 'fname'])
df
# Out:
#       pclass                                               name  gender   age  \
# 0          1                                      Gladys Cherry  Female  30.0
# 1          1          of (Lucy Noel Martha Dyer-Edwards) Rothes  Female  33.0
# 2          1                                     Roberta Maioni  Female  16.0
# 3          1                                       Ruth Taussig  Female  18.0
# 4          1                   Emil (Tillie Mandelbaum) Taussig  Female  39.0
# ...      ...                                                ...     ...   ...
# 1304       1  Herbert Fuller (Carrie Constance Toogood) Chaffee  Female  47.0
# 1305       1                             Herbert Fuller Chaffee    Male  46.0
# 1306       2                                      Walter Harris    Male  30.0
# 1307       1                              Edward Gifford Crosby    Male  70.0
# 1308       1                                   Harriet R Crosby  Female  36.0
#
# ...

# %%
pd.cut(df['age'], bins=[0, 2, 15, 30, 59, 100], labels=["Infant", "Child", "Teen", "Adult", "Senior"])
# (0-2) --> 2 is inclusive and 0 is exclusive
# (2-15) --> 2 is exclusive and 15 is inclusive
# Out:
# 0         Teen
# 1        Adult
# 2         Teen
# 3         Teen
# 4        Adult
#          ...
# 1304     Adult
# 1305     Adult
# 1306      Teen
# 1307    Senior
# 1308     Adult
# Name: age, Length: 1309, dtype: category
# Categories (5, object): ['Infant' < 'Child' < 'Teen' < 'Adult' < 'Senior']

# %%
df['age_category'] = pd.cut(df['age'], bins=[0, 2, 15, 30, 59, 100], labels=["Infant", "Child", "Teen", "Adult", "Senior"])
df
# Out:
#       pclass                                               name  gender   age  \
# 0          1                                      Gladys Cherry  Female  30.0
# 1          1          of (Lucy Noel Martha Dyer-Edwards) Rothes  Female  33.0
# 2          1                                     Roberta Maioni  Female  16.0
# 3          1                                       Ruth Taussig  Female  18.0
# 4          1                   Emil (Tillie Mandelbaum) Taussig  Female  39.0
# ...      ...                                                ...     ...   ...
# 1304       1  Herbert Fuller (Carrie Constance Toogood) Chaffee  Female  47.0
# 1305       1                             Herbert Fuller Chaffee    Male  46.0
# 1306       2                                      Walter Harris    Male  30.0
# 1307       1                              Edward Gifford Crosby    Male  70.0
# 1308       1                                   Harriet R Crosby  Female  36.0
#
# ...

# %%
df['courtesy_title'].unique()
# Out:
# array(['Miss', 'the Countess', 'Mrs', 'Mr', 'Dr', 'Major', 'Master',
#        'Col', 'Lady', 'Jonkheer', 'Rev', 'Ms', 'Mlle', 'Mme', 'Sir',
#        'Don', 'Dona', 'Capt'], dtype=object)

# %%
def social_status(row):
    if row['courtesy_title'] in ['Miss', 'Mrs', 'Mr', 'Master', 'Ms', 'Mlle']:
        return 'Common'
    elif row['courtesy_title'] in ['Don', 'Dona', 'the Countess', 'Sir', 'Lady']:
        return 'Royal'
    if row['courtesy_title'] in ['Capt', 'Major', 'Col']:
        return 'Military'
    else:
        return 'Other Profession'

# %%
df['social_status'] = df.apply(social_status, axis=1)
df
# Out:
#       pclass                                               name  gender   age  \
# 0          1                                      Gladys Cherry  Female  30.0
# 1          1          of (Lucy Noel Martha Dyer-Edwards) Rothes  Female  33.0
# 2          1                                     Roberta Maioni  Female  16.0
# 3          1                                       Ruth Taussig  Female  18.0
# 4          1                   Emil (Tillie Mandelbaum) Taussig  Female  39.0
# ...      ...                                                ...     ...   ...
# 1304       1  Herbert Fuller (Carrie Constance Toogood) Chaffee  Female  47.0
# 1305       1                             Herbert Fuller Chaffee    Male  46.0
# 1306       2                                      Walter Harris    Male  30.0
# 1307       1                              Edward Gifford Crosby    Male  70.0
# 1308       1                                   Harriet R Crosby  Female  36.0
#
# ...

# %%
df.loc[df['fam_cnt'] == 0]
# Out:
#       pclass                                       name  gender   age  sibsp  \
# 0          1                              Gladys Cherry  Female  30.0      0
# 1          1  of (Lucy Noel Martha Dyer-Edwards) Rothes  Female  33.0      0
# 2          1                             Roberta Maioni  Female  16.0      0
# 6          1                  Walter Chamberlain Porter    Male  47.0      0
# 7          1                     George Quincy Clifford    Male  28.0      0
# ...      ...                                        ...     ...   ...    ...
# 1291       2                       Percy Thomas Oxenham    Male  22.0      0
# 1292       2                 Reginald Charles Coleridge    Male  29.0      0
# 1293       2                       (Selena Rogers) Cook  Female  22.0      0
# 1303       3                      Alice Phoebe Harknett  Female  28.0      0
# 1306       2                              Walter Harris    Male  30.0      0
#
# ...

# %%
tick = df.loc[(df['fam_cnt']+1 != df['psg_cnt']), 'ticket'].unique()

# %%
def comp_type(row):
    if row['psg_cnt'] == 1:
        return "Solo"
    else:
        if (row['fam_cnt'] + 1 == row['psg_cnt']) or (row['fam_cnt'] >= row['psg_cnt']):
            return 'Family'
        elif row['ticket'] in tick:
            return 'Family + Friends'
        else:
            return 'Friends'

# finding solo, friends and family + friends

df['companion_type'] = df.apply(comp_type, axis=1)
df
# Out:
#       pclass                                               name  gender   age  \
# 0          1                                      Gladys Cherry  Female  30.0
# 1          1          of (Lucy Noel Martha Dyer-Edwards) Rothes  Female  33.0
# 2          1                                     Roberta Maioni  Female  16.0
# 3          1                                       Ruth Taussig  Female  18.0
# 4          1                   Emil (Tillie Mandelbaum) Taussig  Female  39.0
# ...      ...                                                ...     ...   ...
# 1304       1  Herbert Fuller (Carrie Constance Toogood) Chaffee  Female  47.0
# 1305       1                             Herbert Fuller Chaffee    Male  46.0
# 1306       2                                      Walter Harris    Male  30.0
# 1307       1                              Edward Gifford Crosby    Male  70.0
# 1308       1                                   Harriet R Crosby  Female  36.0
#
# ...

# %%
df.loc[df['companion_type'] == 'Solo', ['ticket', 'gender', 'sibsp', 'parch', 'fam_cnt', 'psg_cnt']]
# Out:
#            ticket  gender  sibsp  parch  fam_cnt  psg_cnt
# 8          110469    Male      0      0        0        1
# 9          110489    Male      0      0        0        1
# 10         110564    Male      0      0        0        1
# 13         111163    Male      0      0        0        1
# 14         111240    Male      0      0        0        1
# ...           ...     ...    ...    ...      ...      ...
# 1291  W./C. 14260    Male      0      0        0        1
# 1292  W./C. 14263    Male      0      0        0        1
# 1293  W./C. 14266  Female      0      0        0        1
# 1303   W./C. 6609  Female      0      0        0        1
# 1306    W/C 14208    Male      0      0        0        1
#
# [713 rows x 6 columns]

# %%
df.loc[df['companion_type'] == 'Friends', ['ticket', 'gender', 'sibsp', 'parch', 'fam_cnt', 'psg_cnt']]
# Out:
# Empty DataFrame
# Columns: [ticket, gender, sibsp, parch, fam_cnt, psg_cnt]
# Index: []

# %%
df.loc[(df['companion_type'] == 'Friends') & (df['fam_cnt'] > 0), ['ticket', 'gender', 'sibsp', 'parch', 'fam_cnt', 'psg_cnt']]
# Out:
# Empty DataFrame
# Columns: [ticket, gender, sibsp, parch, fam_cnt, psg_cnt]
# Index: []

# %%
df.loc[df['companion_type'] == 'Family', ['ticket', 'gender', 'sibsp', 'parch', 'fam_cnt', 'psg_cnt']]
# Out:
#            ticket  gender  sibsp  parch  fam_cnt  psg_cnt
# 3          110413  Female      0      2        2        3
# 4          110413  Female      1      1        2        3
# 5          110413    Male      1      1        2        3
# 11         110813    Male      1      0        1        2
# 12         110813  Female      1      0        1        2
# ...           ...     ...    ...    ...      ...      ...
# 1302   W./C. 6608    Male      2      2        4        5
# 1304  W.E.P. 5734  Female      1      0        1        2
# 1305  W.E.P. 5734    Male      1      0        1        2
# 1307    WE/P 5735    Male      1      1        2        2
# 1308    WE/P 5735  Female      0      2        2        2
#
# [396 rows x 6 columns]

# %%
df.loc[(df['companion_type'] == 'Family') & (df['fam_cnt'] + 1 != df['psg_cnt']), ['ticket', 'gender', 'sibsp', 'parch', 'fam_cnt', 'psg_cnt']]
# Out:
#           ticket  gender  sibsp  parch  fam_cnt  psg_cnt
# 103        11751  Female      1      1        2        2
# 104        11751    Male      1      1        2        2
# 114        11769  Female      2      0        2        2
# 115        11769  Female      2      0        2        2
# 147        13567    Male      1      1        2        2
# 148        13567  Female      1      1        2        2
# 274       237789  Female      0      2        2        2
# 275       237789  Female      1      1        2        2
# 296       243847  Female      2      1        3        2
# 338       250649  Female      0      2        2        2
# 339       250649    Male      1      1        2        2
# 341       250651  Female      1      1        2        2
# 342       250651    Male      1      1        2        2
# 353         2625  Female      1      1        2        2
# 475        29105  Female      1      3        4        2
# ...

# %%
df.loc[df['ticket'] == "113781"]
# Out:
#     pclass                                       name  gender   age  sibsp  \
# 71       1                      Hudson Trevor Allison    Male   0.9      1
# 72       1                      Helen Loraine Allison  Female   2.0      1
# 73       1            Hudson Joshua Creighton Allison    Male  30.0      1
# 74       1                              Alice Cleaver  Female  22.0      0
# 75       1  Hudson J C (Bessie Waldo Daniels) Allison  Female  25.0      1
# 76       1                              Sarah Daniels  Female  33.0      0
#
#     parch  ticket  fare         port  survived courtesy_title  fam_cnt  \
# 71      2  113781  25.3  Southampton         1         Master        3
# 72      2  113781  25.3  Southampton         0           Miss        3
# 73      2  113781  25.3  Southampton         0             Mr        3
# 74      0  113781  25.3  Southampton         1           Miss        0
# 75      2  113781  25.3  Southampton         0            Mrs        3
# ...

# %%
df.loc[df['ticket'] == "S.O.C. 14879"]
# Out:
#       pclass                    name gender   age  sibsp  parch        ticket  \
# 1203       2    Leonard Mark Hickman   Male  24.0      2      0  S.O.C. 14879
# 1204       2    Percy William Deacon   Male  17.0      0      0  S.O.C. 14879
# 1205       2  Stanley George Hickman   Male  21.0      2      0  S.O.C. 14879
# 1206       2    Charles Henry Davies   Male  18.0      0      0  S.O.C. 14879
# 1207       2         Ambrose Jr Hood   Male  21.0      0      0  S.O.C. 14879
# 1208       2          William Dibden   Male  18.0      0      0  S.O.C. 14879
# 1209       2           Lewis Hickman   Male  32.0      2      0  S.O.C. 14879
#
#       fare         port  survived courtesy_title  fam_cnt  psg_cnt  \
# 1203  10.5  Southampton         0             Mr        2        7
# 1204  10.5  Southampton         0             Mr        0        7
# 1205  10.5  Southampton         0             Mr        2        7
# 1206  10.5  Southampton         0             Mr        0        7
# ...

# %% [markdown]
# # rearrange column orders

# %%
df.columns
# Out:
# Index(['pclass', 'name', 'gender', 'age', 'sibsp', 'parch', 'ticket', 'fare',
#        'port', 'survived', 'courtesy_title', 'fam_cnt', 'psg_cnt',
#        'age_category', 'social_status', 'companion_type'],
#       dtype='object')

# %%
l = ['ticket', 'courtesy_title', 'name', 'gender', 'age', 'age_category', 'social_status', 'fam_cnt', 
     'companion_type', 'psg_cnt', 'pclass', 'fare', 'port', 'survived']

# %%
df = df[l]
df
# Out:
#            ticket courtesy_title  \
# 0          110152           Miss
# 1          110152   the Countess
# 2          110152           Miss
# 3          110413           Miss
# 4          110413            Mrs
# ...           ...            ...
# 1304  W.E.P. 5734            Mrs
# 1305  W.E.P. 5734             Mr
# 1306    W/C 14208             Mr
# 1307    WE/P 5735           Capt
# 1308    WE/P 5735           Miss
#
#                                                    name  gender   age  \
# 0                                         Gladys Cherry  Female  30.0
# 1             of (Lucy Noel Martha Dyer-Edwards) Rothes  Female  33.0
# 2                                        Roberta Maioni  Female  16.0
# 3                                          Ruth Taussig  Female  18.0
# 4                      Emil (Tillie Mandelbaum) Taussig  Female  39.0
# ...                                                 ...     ...   ...
# ...

# %%
df.describe()
# Out:
#                age      fam_cnt      psg_cnt       pclass         fare  \
# count  1309.000000  1309.000000  1309.000000  1309.000000  1309.000000
# mean     29.503209     0.883881     2.101604     2.294882    14.757601
# std      12.905189     1.583639     1.779832     0.837836    13.550806
# min       0.200000     0.000000     1.000000     1.000000     0.000000
# 25%      22.000000     0.000000     1.000000     2.000000     7.600000
# 50%      28.000000     0.000000     1.000000     3.000000     8.000000
# 75%      35.000000     1.000000     3.000000     3.000000    15.000000
# max      80.000000    10.000000    11.000000     3.000000   128.100000
#
#           survived
# count  1309.000000
# mean      0.381971
# std       0.486055
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df[['age', 'fare', 'pclass', 'survived']].describe()
# Out:
#                age         fare       pclass     survived
# count  1309.000000  1309.000000  1309.000000  1309.000000
# mean     29.503209    14.757601     2.294882     0.381971
# std      12.905189    13.550806     0.837836     0.486055
# min       0.200000     0.000000     1.000000     0.000000
# 25%      22.000000     7.600000     2.000000     0.000000
# 50%      28.000000     8.000000     3.000000     0.000000
# 75%      35.000000    15.000000     3.000000     1.000000
# max      80.000000   128.100000     3.000000     1.000000

# %%
df.loc[df['fare'] == 0]
# Out:
#       ticket courtesy_title                              name gender   age  \
# 22    112050             Mr                 Thomas Jr Andrews   Male  39.0
# 23    112051             Mr  Roderick Robert Crispin Chisholm   Male  28.0
# 24    112052             Mr          William Henry Marsh Parr   Male  28.0
# 26    112058             Mr                Joseph Bruce Ismay   Male  49.0
# 27    112058             Mr                       Richard Fry   Male  28.0
# 28    112059             Mr                  William Harrison   Male  40.0
# 206    19972       Jonkheer              John George Reuchlin   Male  38.0
# 278   239853             Mr            Francis "Frank" Parkes   Male  28.0
# 279   239853             Mr         Alfred Fleming Cunningham   Male  28.0
# 280   239853             Mr                  William Campbell   Male  28.0
# 281   239854             Mr       Anthony Wood "Archie" Frost   Male  28.0
# ...

# %%
df.loc[df['fare'] == 0].shape
# Out:
# (17, 14)

# %%
new_df = df.loc[df['fare'] == 0]
new_df
# Out:
#       ticket courtesy_title                              name gender   age  \
# 22    112050             Mr                 Thomas Jr Andrews   Male  39.0
# 23    112051             Mr  Roderick Robert Crispin Chisholm   Male  28.0
# 24    112052             Mr          William Henry Marsh Parr   Male  28.0
# 26    112058             Mr                Joseph Bruce Ismay   Male  49.0
# 27    112058             Mr                       Richard Fry   Male  28.0
# 28    112059             Mr                  William Harrison   Male  40.0
# 206    19972       Jonkheer              John George Reuchlin   Male  38.0
# 278   239853             Mr            Francis "Frank" Parkes   Male  28.0
# 279   239853             Mr         Alfred Fleming Cunningham   Male  28.0
# 280   239853             Mr                  William Campbell   Male  28.0
# 281   239854             Mr       Anthony Wood "Archie" Frost   Male  28.0
# ...

# %%
new_df.index
# Out:
# Index([  22,   23,   24,   26,   27,   28,  206,  278,  279,  280,  281,  282,
#         283, 1089, 1090, 1091, 1092],
#       dtype='int64')

# %%
df = df.drop(index=new_df.index)
df = df.reset_index(drop=True)
df
# Out:
#            ticket courtesy_title  \
# 0          110152           Miss
# 1          110152   the Countess
# 2          110152           Miss
# 3          110413           Miss
# 4          110413            Mrs
# ...           ...            ...
# 1287  W.E.P. 5734            Mrs
# 1288  W.E.P. 5734             Mr
# 1289    W/C 14208             Mr
# 1290    WE/P 5735           Capt
# 1291    WE/P 5735           Miss
#
#                                                    name  gender   age  \
# 0                                         Gladys Cherry  Female  30.0
# 1             of (Lucy Noel Martha Dyer-Edwards) Rothes  Female  33.0
# 2                                        Roberta Maioni  Female  16.0
# 3                                          Ruth Taussig  Female  18.0
# 4                      Emil (Tillie Mandelbaum) Taussig  Female  39.0
# ...                                                 ...     ...   ...
# ...

# %%
new_df = new_df.reset_index(drop=True)
new_df
# Out:
#     ticket courtesy_title                              name gender   age  \
# 0   112050             Mr                 Thomas Jr Andrews   Male  39.0
# 1   112051             Mr  Roderick Robert Crispin Chisholm   Male  28.0
# 2   112052             Mr          William Henry Marsh Parr   Male  28.0
# 3   112058             Mr                Joseph Bruce Ismay   Male  49.0
# 4   112058             Mr                       Richard Fry   Male  28.0
# 5   112059             Mr                  William Harrison   Male  40.0
# 6    19972       Jonkheer              John George Reuchlin   Male  38.0
# 7   239853             Mr            Francis "Frank" Parkes   Male  28.0
# 8   239853             Mr         Alfred Fleming Cunningham   Male  28.0
# 9   239853             Mr                  William Campbell   Male  28.0
# 10  239854             Mr       Anthony Wood "Archie" Frost   Male  28.0
# 11  239855             Mr                   Robert J Knight   Male  28.0
# ...

# %% [markdown]
# # Data analysis using visuals

# %% [markdown]
# # Count plot

# %%
plt.figure(figsize=(3,2)) # width & height
sns.countplot(df, x='pclass')
plt.xlabel('passenger class')
plt.ylabel('no of psgs')
plt.title('pclass whise psg_cnt')
plt.show()

# %%
plt.figure(figsize=(4,3)) # width & height
sns.countplot(df, x='pclass', order=[3,1,2])

plt.title('pclass whise psg_cnt')
plt.yticks(range(0, 701, 50))
plt.xticks(ticks = [0, 1, 2], labels=['Third', 'First', 'Second'])
plt.show()

# %%
plt.figure(figsize=(4,4))
c = sns.countplot(df, x='gender')
c.bar_label(c.containers[0])
plt.title("Gender wise no of passengers")
plt.show()

# %%
sns.countplot(df, x="pclass", hue="gender")
plt.title("pclass wise gender count")
# Out:
# Text(0.5, 1.0, 'pclass wise gender count')

# %%
c = sns.countplot(df, x="pclass", hue="gender")
for i in c.containers:
    c.bar_label(i)
plt.title("pclass wise gender count")
# Out:
# Text(0.5, 1.0, 'pclass wise gender count')

# %% [markdown]
# # Barplot

# %%
sns.barplot(df, x="gender", y="fare", estimator="sum")
plt.show()

# %%
sns.barplot(df, x="gender", y="fare", estimator="sum", errorbar=None)
plt.title("Gender wise total fare")
# Out:
# Text(0.5, 1.0, 'Gender wise total fare')

# %%
c = sns.barplot(df, x="gender", y="fare", estimator="sum", errorbar=None, hue="survived")
for i in c.containers:
    c.bar_label(i, padding=-15)
plt.title("Gender wise total fare")
plt.show()

# %%
c = sns.barplot(df, x="companion_type", y="fare", estimator="mean", errorbar=None)
for i in c.containers:
    c.bar_label(i, padding=-15)
plt.title("companion wise average fare")
# Out:
# Text(0.5, 1.0, 'companion wise average fare')

# %%
c = sns.barplot(df, x="companion_type", y="fare", estimator="mean", errorbar=None, hue="gender", palette=["purple", "violet"])
for i in c.containers:
    c.bar_label(i, padding=-15)
plt.title("gender wise average fare")
# Out:
# Text(0.5, 1.0, 'gender wise average fare')

# %% [markdown]
# Piechart

# %%
p_cnt = df['pclass'].value_counts()
p_cnt
print(p_cnt.index)
print(p_cnt.values)
# Out:
# Index([3, 1, 2], dtype='int64', name='pclass')
# [705 316 271]

# %%
plt.figure(figsize=(2,2))
plt.pie(p_cnt.values)
plt.show()

# %%
plt.figure(figsize=(4,4))
plt.pie(x=p_cnt.values, labels=p_cnt.index, autopct="%.1f%%")
plt.show()

# %%
plt.figure(figsize=(4,4))
plt.pie(x=p_cnt.values, labels=p_cnt.index, autopct="%.1f%%", explode=[0,0,0.1])
plt.show()

# %%
df.describe()
# Out:
#                age      fam_cnt      psg_cnt       pclass         fare  \
# count  1292.000000  1292.000000  1292.000000  1292.000000  1292.000000
# mean     29.468034     0.895511     2.100619     2.301084    14.951780
# std      12.953228     1.590759     1.785760     0.836743    13.532803
# min       0.200000     0.000000     1.000000     1.000000     3.200000
# 25%      22.000000     0.000000     1.000000     2.000000     7.700000
# 50%      28.000000     0.000000     1.000000     3.000000     8.050000
# 75%      35.000000     1.000000     3.000000     3.000000    15.000000
# max      80.000000    10.000000    11.000000     3.000000   128.100000
#
#           survived
# count  1292.000000
# mean      0.385449
# std       0.486890
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# # observation
# Passengers fare is around 14.9Rs with avg fluctation of 13.5Rs and 68% passengers fare amount ranges lies from 1.4 - 28.4

# %% [markdown]
# # Scatter plot

# %%
plt.figure(figsize=(14,9))
sns.scatterplot(df, x="age", y="fare")
plt.title("Age wise fare count")
plt.show()

# %% [markdown]
# Data points are less scattered, meaning the data points are near to each other

# %%
plt.figure(figsize=(10,9))
sns.scatterplot(df, x="age", y="fare", hue="gender")
plt.title("Age wise fare count")
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.scatterplot(df, x="age", y="fare", hue="pclass", palette="Set1", style="gender", markers=["v", "*"])
plt.title("Age wise fare count")
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.scatterplot(df, x="age", y="fare", hue="gender", palette=["red", "blue", "green"], markers=["v", "*"])
plt.title("Age wise fare count")
plt.show()
# Out:
# C:\Users\Suraj Kumar\AppData\Local\Temp\ipykernel_9432\2613239439.py:2: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.scatterplot(df, x="age", y="fare", hue="gender", palette=["red", "blue", "green"], markers=["v", "*"])

# %% [markdown]
# # facetgrid

# %%
fg = sns.FacetGrid(df, col='gender')
# fg.map_dataframe(sns.countplot, x="gender")

# %%
fg = sns.FacetGrid(df, col='gender', height=10)

# %%
fg = sns.FacetGrid(df, col='gender', height=10, aspect=2)

# %%
fg = sns.FacetGrid(df, col='gender', height=5, aspect=1.5)
fg.map_dataframe(sns.countplot, x="pclass")
plt.show()

# %%
fg = sns.FacetGrid(df, col="gender")
fg.map_dataframe(sns.countplot, x="pclass", hue="survived", palette=["red", "green"], hue_order=[0,1])
plt.legend(["not survived", "survived"])
plt.show()

# %%
fg = sns.FacetGrid(df, col="gender")
fg.map_dataframe(sns.barplot, x="pclass", y="survived", estimator="mean", errorbar=None)
plt.show()

# %%
df
# Out:
#            ticket courtesy_title  \
# 0          110152           Miss
# 1          110152   the Countess
# 2          110152           Miss
# 3          110413           Miss
# 4          110413            Mrs
# ...           ...            ...
# 1287  W.E.P. 5734            Mrs
# 1288  W.E.P. 5734             Mr
# 1289    W/C 14208             Mr
# 1290    WE/P 5735           Capt
# 1291    WE/P 5735           Miss
#
#                                                    name  gender   age  \
# 0                                         Gladys Cherry  Female  30.0
# 1             of (Lucy Noel Martha Dyer-Edwards) Rothes  Female  33.0
# 2                                        Roberta Maioni  Female  16.0
# 3                                          Ruth Taussig  Female  18.0
# 4                      Emil (Tillie Mandelbaum) Taussig  Female  39.0
# ...                                                 ...     ...   ...
# ...

# %%
fg = sns.FacetGrid(df, col="gender")
fg.map_dataframe(sns.barplot, x="pclass", y="survived", estimator="mean", errorbar=None)
plt.show()

# %%
fg = sns.FacetGrid(df, row="pclass", height=5, aspect=1.5)
fg.map_dataframe(sns.scatterplot, x="age", y="fare", hue="survived", hue_order=[1, 0], palette=["green", "red"])
plt.legend(["survived", "not survived"])
plt.show()

# %% [markdown]
# # Boxplot

# %%
plt.figure(figsize=(7,5))
sns.boxplot(df, x="age")
plt.show()

# the datapoint far away from majority of data points are called outliers
# whisker min and max point by excluding outliers
# Inter Quartile Range (IQR)
# blue box (25%, 50%, 75%)
# 25%-----> Quartile 1
# 50%-----> Quartile 2 (Median)
# 75%-----> Quartile 3

# %%
plt.figure(figsize=(9,5))
sns.boxplot(df, x="fare")
# Out:
# <Axes: xlabel='fare'>

# %%
plt.figure(figsize=(11,2))
sns.histplot(df, x="age")
plt.xticks(range(0, 84, 2))
plt.show()

# %% [markdown]
# **observation** The range between 26 - 28 most of the people are travelling

# %%
plt.figure(figsize=(15,5))
sns.histplot(df, x="fare")
plt.xticks(range(0, 135, 3))
plt.show()

# %% [markdown]
# most of the people are travelling between 6 - 9rs

# %%
plt.figure(figsize=(7,5))
sns.kdeplot(df, x="age", bw_adjust=0.5)
plt.xticks(range(0, 85, 6))
plt.grid()
plt.show()

# %% [markdown]
# **observation:** most of the peoplare are travelling between the age of 24 - 30. And it is slightly right skewed

# %%
plt.figure(figsize=(15,3))
sns.kdeplot(df, x="fare", bw_adjust=0.5)
plt.xticks(range(0, 145, 5))
plt.grid()
plt.show()

# %% [markdown]
# Most of the people are preferring lower fare amount between 5 - 11 and it is completely right skewed
